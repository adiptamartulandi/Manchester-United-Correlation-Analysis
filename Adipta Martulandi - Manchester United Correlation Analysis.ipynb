# %% [markdown]
# ## 1. Load Library

# %%
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 2. Dataset Description

# %% [markdown]
# ### Context
# Official football data organised and formatted in csv files ready for download is quite hard to come by. Stats providers are hesitant to release their data to anyone and everyone, even if it's for academic purposes. That was my exact dilemma which prompted me to scrape and extract it myself. Now that it's at your disposal, have fun with it.
#
# ### Content
# The data was acquired from the Premier League website and is representative of seasons 2006/2007 to 2017/2018. Visit both sets to get a detailed description of what each entails.
#
# ### Inspiration
# Use it to the best of your ability to predict match outcomes or for a thorough data analysis to uncover some intriguing insights. Be safe and only use this dataset for personal projects. If you'd like to use this type of data for a commercial project, contact Opta to access it through their API instead.

# %% [markdown]
# ## 3. Load Datasets

# %%
df = pd.read_csv('stats.csv')

# %%
df.head()
# Out:
#                 team  wins  losses  goals  total_yel_card  total_red_card  \
# 0  Manchester United  28.0     5.0   83.0            60.0             1.0
# 1            Chelsea  24.0     3.0   64.0            62.0             4.0
# 2          Liverpool  20.0    10.0   57.0            44.0             0.0
# 3            Arsenal  19.0     8.0   63.0            59.0             3.0
# 4  Tottenham Hotspur  17.0    12.0   57.0            48.0             3.0
#
#    total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  ...  \
# 0              698.0                 256.0          21.0         12.0  ...
# 1              636.0                 216.0          14.0         16.0  ...
# 2              668.0                 214.0          15.0          8.0  ...
# 3              638.0                 226.0          19.0         10.0  ...
# 4              520.0                 184.0           6.0          5.0  ...
#
#    total_cross  corner_taken  touches  big_chance_missed  clearance_off_line  \
# 0        918.0         258.0  25686.0                NaN                 1.0
# 1        897.0         231.0  24010.0                NaN                 2.0
# 2       1107.0         282.0  24150.0                NaN                 1.0
# 3        873.0         278.0  25592.0                NaN                 1.0
# 4        796.0         181.0  22200.0                NaN                 2.0
#
#    dispossessed  penalty_save  total_high_claim  punches     season
# 0           NaN           2.0              37.0     25.0  2006-2007
# 1           NaN           1.0              74.0     22.0  2006-2007
# 2           NaN           0.0              51.0     27.0  2006-2007
# 3           NaN           0.0              88.0     27.0  2006-2007
# 4           NaN           0.0              51.0     24.0  2006-2007
#
# [5 rows x 42 columns]

# %% [markdown]
# ## 4. Manchester United Data

# %%
utd = df[df['team']=='Manchester United']

# %%
utd.head()
# Out:
#                  team  wins  losses  goals  total_yel_card  total_red_card  \
# 0   Manchester United  28.0     5.0   83.0            60.0             1.0
# 20  Manchester United  27.0     5.0   80.0            51.0             2.0
# 40  Manchester United  28.0     4.0   68.0            61.0             5.0
# 61  Manchester United  27.0     7.0   86.0            49.0             4.0
# 80  Manchester United  23.0     4.0   78.0            56.0             3.0
#
#     total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  ...  \
# 0               698.0                 256.0          21.0         12.0  ...
# 20              696.0                 260.0          16.0         12.0  ...
# 40              715.0                 230.0           9.0          7.0  ...
# 61              695.0                 221.0          12.0         14.0  ...
# 80              618.0                 212.0          15.0         18.0  ...
#
#     total_cross  corner_taken  touches  big_chance_missed  clearance_off_line  \
# 0         918.0         258.0  25686.0                NaN                 1.0
# 20        936.0         261.0  26620.0                NaN                10.0
# 40       1039.0         257.0  30077.0                NaN                 3.0
# 61       1156.0         297.0  28968.0                NaN                 2.0
# 80       1005.0         243.0  26671.0               50.0                 2.0
#
#     dispossessed  penalty_save  total_high_claim  punches     season
# 0            NaN           2.0              37.0     25.0  2006-2007
# 20         627.0           0.0              47.0     23.0  2007-2008
# 40         579.0           0.0              56.0     22.0  2008-2009
# 61         622.0           0.0              65.0     18.0  2009-2010
# 80         471.0           0.0              45.0     16.0  2010-2011
#
# [5 rows x 42 columns]

# %% [markdown]
# ### 4.1 Features Description

# %% [markdown]
# 1. team = team name
# 2. wins = wins
# 3. losses = losses
# 4. goals = goals scored
# 5. total_yel_card = yellow cards
# 6. total_red_card = red cards
# 7. total_scoring_att = shots
# 8. ontarget_scoring_att = shots on target
# 9. hit_woodwork = shots that hit the bar/post/woodwork
# 10. att_hd_goal = goals from headers
# 11. att_pen_goal = goals from penalties
# 12. att_freekick_goal = goals from free-kicks
# 13. att_ibox_goal = goals from inside the box
# 14. att_obox_goal = goals from outside the box
# 15. goal_fastbreak = goals from counter attacks
# 16. total_offside = offsides
# 17. clean_sheet = clean sheats
# 18. goals_conceded = goals conceded
# 19. saves = saves
# 20. outfielder_bloc = kblocks
# 21. interception = interceptions
# 22. total_tackle = tackles
# 23. last_man_tackle = last-man tackles
# 24. total_clearance = clearances
# 25. head_clearance = headed clearances
# 26. own_goals = own goals
# 27. penalty_conceded = penalties conceded
# 28. pen_goals_conceded = goals conceded from penalties
# 29. total_pass = passes
# 30. total_through_ball = through balls
# 31. total_long_balls = long balls
# 32. backward_pass = backwards passes
# 33. total_cross = crosses
# 34. corner_taken = corners
# 35. touches = touches
# 36. big_chance_missed = big chances missed
# 37. clearance_off_line = clearances off-the-line
# 38. dispossessed = dispossessed
# 39. penalty_save = penalties saved
# 40. total_high_claim = high claims by goalkeeper
# 41. punches = punches by goalkeeper
# 42. seasoncorresponding = season of statistics

# %% [markdown]
# ### 4.2 Sneak Peak to Data

# %%
#Ada 12 rows yang berarti 12 musim dari tahun 06/07 sampai dengan 17/18
utd.shape
# Out:
# (12, 42)

# %%
#Hampir semua data typenya float kecuali team dan season yang tipenya object
utd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12 entries, 0 to 221
# Data columns (total 42 columns):
# team                    12 non-null object
# wins                    12 non-null float64
# losses                  12 non-null float64
# goals                   12 non-null float64
# total_yel_card          12 non-null float64
# total_red_card          12 non-null float64
# total_scoring_att       12 non-null float64
# ontarget_scoring_att    12 non-null float64
# hit_woodwork            12 non-null float64
# att_hd_goal             12 non-null float64
# att_pen_goal            12 non-null float64
# att_freekick_goal       12 non-null float64
# att_ibox_goal           12 non-null float64
# att_obox_goal           12 non-null float64
# goal_fastbreak          12 non-null float64
# total_offside           12 non-null float64
# clean_sheet             12 non-null float64
# goals_conceded          12 non-null float64
# saves                   11 non-null float64
# outfielder_block        12 non-null float64
# interception            12 non-null float64
# total_tackle            12 non-null float64
# last_man_tackle         12 non-null float64
# total_clearance         12 non-null float64
# head_clearance          11 non-null float64
# own_goals               12 non-null float64
# penalty_conceded        12 non-null float64
# pen_goals_conceded      12 non-null float64
# total_pass              12 non-null float64
# total_through_ball      11 non-null float64
# total_long_balls        12 non-null float64
# backward_pass           8 non-null float64
# total_cross             12 non-null float64
# corner_taken            12 non-null float64
# touches                 12 non-null float64
# big_chance_missed       8 non-null float64
# clearance_off_line      12 non-null float64
# dispossessed            11 non-null float64
# penalty_save            12 non-null float64
# total_high_claim        12 non-null float64
# punches                 12 non-null float64
# season                  12 non-null object
# dtypes: float64(40), object(2)
# memory usage: 4.0+ KB

# %%
#Statistical Description dari data
utd.describe()
# Out:
#             wins     losses      goals  total_yel_card  total_red_card  \
# count  12.000000  12.000000  12.000000       12.000000       12.000000
# mean   24.166667   6.416667  72.250000       60.166667        2.416667
# std     4.108380   2.503028  13.315234        8.122173        1.564279
# min    18.000000   4.000000  49.000000       49.000000        1.000000
# 25%    19.750000   5.000000  63.500000       54.750000        1.000000
# 50%    26.000000   5.000000  73.000000       60.500000        2.000000
# 75%    28.000000   7.250000  83.750000       64.250000        3.250000
# max    28.000000  12.000000  89.000000       78.000000        5.000000
#
#        total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  \
# count          12.000000             12.000000     12.000000    12.000000
# mean          600.000000            210.833333     15.416667    11.750000
# std            92.920298             34.693026      4.621262     3.646293
# min           430.000000            144.000000      9.000000     5.000000
# 25%           522.500000            182.250000     11.750000     9.750000
# 50%           604.500000            212.500000     16.000000    12.000000
# 75%           695.250000            233.250000     17.500000    14.000000
# max           715.000000            260.000000     24.000000    18.000000
#
#        att_pen_goal  ...  backward_pass  total_cross  corner_taken  \
# count     12.000000  ...       8.000000    12.000000     12.000000
# mean       4.333333  ...    2941.750000   944.083333    242.333333
# std        2.059715  ...     330.332625   112.542080     27.923054
# min        1.000000  ...    2411.000000   753.000000    214.000000
# 25%        3.000000  ...    2755.500000   893.000000    217.750000
# 50%        4.000000  ...    2888.000000   949.000000    235.500000
# 75%        5.250000  ...    3188.000000  1008.250000    258.750000
# max        9.000000  ...    3457.000000  1156.000000    297.000000
#
#             touches  big_chance_missed  clearance_off_line  dispossessed  \
# count     12.000000           8.000000           12.000000     11.000000
# mean   27749.666667          47.500000            3.416667    501.818182
# std     1206.754802          12.603854            2.539088     85.481949
# min    25686.000000          28.000000            1.000000    389.000000
# 25%    27115.750000          41.000000            1.750000    435.000000
# 50%    27533.500000          46.500000            3.000000    506.000000
# 75%    28331.250000          53.500000            4.250000    550.500000
# max    30077.000000          65.000000           10.000000    627.000000
#
#        penalty_save  total_high_claim    punches
# count     12.000000         12.000000  12.000000
# mean       0.416667         39.250000  16.833333
# std        0.668558         12.314995   8.222290
# min        0.000000         20.000000   4.000000
# 25%        0.000000         32.000000  11.500000
# 50%        0.000000         37.000000  17.000000
# 75%        1.000000         45.500000  23.500000
# max        2.000000         65.000000  28.000000
#
# [8 rows x 40 columns]

# %% [markdown]
# ## 5. Data Preprocessing

# %% [markdown]
# ### 5.1 Handling Missing Values

# %%
utd.isnull().sum()
# Out:
# team                    0
# wins                    0
# losses                  0
# goals                   0
# total_yel_card          0
# total_red_card          0
# total_scoring_att       0
# ontarget_scoring_att    0
# hit_woodwork            0
# att_hd_goal             0
# att_pen_goal            0
# att_freekick_goal       0
# att_ibox_goal           0
# att_obox_goal           0
# goal_fastbreak          0
# total_offside           0
# clean_sheet             0
# goals_conceded          0
# saves                   1
# outfielder_block        0
# interception            0
# total_tackle            0
# last_man_tackle         0
# total_clearance         0
# head_clearance          1
# own_goals               0
# penalty_conceded        0
# pen_goals_conceded      0
# total_pass              0
# total_through_ball      1
# total_long_balls        0
# backward_pass           4
# total_cross             0
# corner_taken            0
# touches                 0
# big_chance_missed       4
# clearance_off_line      0
# dispossessed            1
# penalty_save            0
# total_high_claim        0
# punches                 0
# season                  0
# dtype: int64

# %%
utd['saves'] = utd['saves'].fillna(0)

# %%
utd['head_clearance'] = utd['head_clearance'].fillna(686)

# %%
utd['total_through_ball'] = utd['total_through_ball'].fillna(utd['total_through_ball'].median())

# %%
utd['dispossessed'] = utd['dispossessed'].fillna(utd['dispossessed'].median())

# %% [markdown]
# ### 5. Remove Unused Columns

# %%
dropped = ['backward_pass', 'big_chance_missed', 'team', 'total_yel_card', 'total_red_card', 'hit_woodwork',
           'total_offside', 'saves', 'own_goals', 'corner_taken', 'big_chance_missed', 'penalty_save', 'penalty_save'
          ,'total_high_claim', 'punches','att_hd_goal', 'att_pen_goal', 'att_freekick_goal', 'att_ibox_goal',
           'att_obox_goal','penalty_conceded', 'pen_goals_conceded', 'head_clearance', 'clearance_off_line']
utd.drop(columns=dropped, inplace=True)

# %%
utd.head()
# Out:
#     wins  losses  goals  total_scoring_att  ontarget_scoring_att  \
# 0   28.0     5.0   83.0              698.0                 256.0
# 20  27.0     5.0   80.0              696.0                 260.0
# 40  28.0     4.0   68.0              715.0                 230.0
# 61  27.0     7.0   86.0              695.0                 221.0
# 80  23.0     4.0   78.0              618.0                 212.0
#
#     goal_fastbreak  clean_sheet  goals_conceded  outfielder_block  \
# 0              9.0         16.0            27.0              81.0
# 20             7.0         21.0            22.0              96.0
# 40            12.0         24.0            24.0             120.0
# 61             6.0         19.0            28.0             100.0
# 80             5.0         15.0            37.0             107.0
#
#     interception  total_tackle  last_man_tackle  total_clearance  total_pass  \
# 0          254.0         890.0              1.0           1222.0     18723.0
# 20         446.0         978.0              2.0           2022.0     17422.0
# 40         640.0         741.0              8.0           1322.0     19416.0
# 61         602.0         828.0             13.0            983.0     19318.0
# 80         646.0         693.0             17.0           1053.0     18870.0
#
#     total_through_ball  total_long_balls  total_cross  touches  dispossessed  \
# 0                 99.0            2397.0        918.0  25686.0         506.0
# 20                90.0            2417.0        936.0  26620.0         627.0
# 40               291.0            2192.0       1039.0  30077.0         579.0
# 61               243.0            2205.0       1156.0  28968.0         622.0
# 80               212.0            2279.0       1005.0  26671.0         471.0
#
#        season
# 0   2006-2007
# 20  2007-2008
# 40  2008-2009
# 61  2009-2010
# 80  2010-2011

# %% [markdown]
# ## 6. Feature Extraction

# %%
#Membuat fitur block, interception dan clearence
utd['defence'] = utd['outfielder_block'] + utd['interception'] + utd['total_clearance']
utd.drop(columns=['outfielder_block', 'interception', 'total_clearance'], inplace=True)

# %%
#Membuat fitur draw
#1 Musim ada 38 pertandingan
utd['draws'] = 38 - utd['wins'] - utd['losses']

# %%
#Rearange columns agar mudah untuk dibaca
utd = utd[['wins', 'losses', 'draws', 'goals', 'goal_fastbreak', 'total_scoring_att', 'ontarget_scoring_att',
          'total_pass', 'total_through_ball', 'total_long_balls', 'total_cross', 'touches', 'clean_sheet', 'dispossessed',
          'goals_conceded', 'total_tackle', 'last_man_tackle', 'defence', 'season']]

# %% [markdown]
# ## 7. Data Analysis

# %% [markdown]
# - Sir Alex Era dari musim 2006/2007 - 2012/2013
# - After Sir Alex Era dari musim 2013/2014 - 2017/2018

# %%
utd.tail()
# Out:
#      wins  losses  draws  goals  goal_fastbreak  total_scoring_att  \
# 146  19.0    12.0    7.0   64.0             1.0              526.0
# 163  20.0     8.0   10.0   62.0             2.0              512.0
# 183  19.0    10.0    9.0   49.0             2.0              430.0
# 205  18.0     5.0   15.0   54.0             5.0              591.0
# 221  25.0     7.0    6.0   68.0             4.0              512.0
#
#      ontarget_scoring_att  total_pass  total_through_ball  total_long_balls  \
# 146                 183.0     18894.0                61.0            2077.0
# 163                 180.0     21311.0                89.0            2969.0
# 183                 144.0     20070.0                43.0            2649.0
# 205                 210.0     20245.0                99.0            2424.0
# 221                 178.0     20064.0                85.0            2308.0
#
#      total_cross  touches  clean_sheet  dispossessed  goals_conceded  \
# 146       1000.0  27367.0         13.0         491.0            43.0
# 163        908.0  29044.0         11.0         393.0            37.0
# 183        786.0  27542.0         18.0         522.0            35.0
# 205        848.0  28119.0         17.0         389.0            29.0
# 221        753.0  27525.0         19.0         399.0            28.0
#
#      total_tackle  last_man_tackle  defence     season
# 146         676.0              4.0   2085.0  2013-2014
# 163         739.0              4.0   1893.0  2014-2015
# 183         760.0              4.0   1445.0  2015-2016
# 205         690.0              4.0   1795.0  2016-2017
# 221         564.0              0.0   1446.0  2017-2018

# %% [markdown]
# ### 7.1 General Analysis
# - Features yang digunakan adalah:
#     1. wins = Jumlah MU menang
#     2. losses = Jumlah MU kalah

# %%
plt.figure(figsize=(10,5))

plt.plot(utd['season'], utd['wins'])
plt.plot(utd['season'], utd['losses'])
plt.xlabel('Season')
plt.ylabel('Numbers')
plt.xticks(rotation=45)

plt.legend(labels=['wins', 'losses'])
plt.show()

# %% [markdown]
# - Secara <b>general</b>, dapat dilihat bahwa sebelum sir alex era MU memiliki kemenangan diatas sekitar 23 pertandingan pada 1 musim.
# - Lalu setelah sir alex era kemenangan MU mulai turun bahkan sampai di bawah angka 20 pertandingan pada 1 musim.
# - Kecuali tahun 2017/2018 yang memiliki kemenangan diatas 20.

# %% [markdown]
# ### 7.2 Attacking Analysis
# - Menggunakan 4 features yaitu:
#     1. goals = total goals
#     2. goal_fastbreak = goals dalam counter attack
#     3. total_scoring_att = total shots
#     4. ontarget_scoring_att = total shots on target

# %%
#Analisis goalsnya dulu
plt.figure(figsize=(10,5))

plt.plot(utd['season'], utd['goals'])
plt.plot(utd['season'], utd['goal_fastbreak'])
plt.xlabel('Season')
plt.ylabel('Numbers')
plt.xticks(rotation=45)

plt.legend(labels=['total goals', 'counter attack'])
plt.show()

# %% [markdown]
# - Pada era sir alex total goalsnya di kisaranangka 70-80 goals, lalu setelah sir alex pensiun total goalsnya  langsung turun di kisaran angka 50-60 pada satu musim.
# - Untuk goals dalam counter attack lebih banyak terjadi di era sir alex.
# - Namun terjadi penurunan yang smooth untuk counter attack goals mulai 2008/2009, mungkin karena Cristiano Ronaldo pindah ?

# %%
#Analisis Shoot
plt.figure(figsize=(10,5))

plt.plot(utd['season'], utd['total_scoring_att'], color='green')
plt.plot(utd['season'], utd['ontarget_scoring_att'], color='red')
plt.xlabel('Season')
plt.ylabel('Numbers')
plt.xticks(rotation=45)

plt.legend(labels=['total shoot', 'shoot on target'])
plt.show()

# %% [markdown]
# - Cukup jelas ya kalo pada era sir alex total shoots kisaran di angka 600-700 lalu setelah sir alex mengalami penurunan di angka 500an.
# - Kecuali pada tahun 2016-2017 yang memiliki total shoot sekitar 600.

# %%
#lihat korelasi
utd[['wins', 'goals', 'goal_fastbreak','total_scoring_att',
     'ontarget_scoring_att']].corr().style.background_gradient().set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_916c40e4_dc5b_11e9_9f7e_309c23131503row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_916c40e4_dc5b_11e9_9f7e_309c23131503row0_col1 {
#             background-color:  #04649e;
#             color:  #f1f1f1;
#         }    #T_916c40e4_dc5b_11e9_9f7e_309c23131503row0_col2 {
#             background-color:  #a1bbda;
#             color:  #000000;
#         }    #T_916c40e4_dc5b_11e9_9f7e_309c23131503row0_col3 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_916c40e4_dc5b_11e9_9f7e_309c23131503row0_col4 {
#             background-color:  #b7c5df;
#             color:  #000000;
#         }    #T_916c40e4_dc5b_11e9_9f7e_309c23131503row1_col0 {
#             background-color:  #197db7;
#             color:  #000000;
#         }    #T_916c40e4_dc5b_11e9_9f7e_309c23131503row1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_916c40e4_dc5b_11e9_9f7e_309c23131503row1_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_916c40e4_dc5b_11e9_9f7e_309c23131503row1_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_916c40e4_dc5b_11e9_9f7e_309c23131503row1_col4 {
#             background-color:  #adc1dd;
#             color:  #000000;
#         }    #T_916c40e4_dc5b_11e9_9f7e_309c23131503row2_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_916c40e4_dc5b_11e9_9f7e_309c23131503row2_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_916c40e4_dc5b_11e9_9f7e_309c23131503row2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_916c40e4_dc5b_11e9_9f7e_309c23131503row2_col3 {
#             background-color:  #b7c5df;
#             color:  #000000;
#         }    #T_916c40e4_dc5b_11e9_9f7e_309c23131503row2_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_916c40e4_dc5b_11e9_9f7e_309c23131503row3_col0 {
#             background-color:  #96b6d7;
#             color:  #000000;
#         }    #T_916c40e4_dc5b_11e9_9f7e_309c23131503row3_col1 {
#             background-color:  #4a98c5;
#             color:  #000000;
#         }    #T_916c40e4_dc5b_11e9_9f7e_309c23131503row3_col2 {
#             background-color:  #1278b4;
#             color:  #f1f1f1;
#         }    #T_916c40e4_dc5b_11e9_9f7e_309c23131503row3_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_916c40e4_dc5b_11e9_9f7e_309c23131503row3_col4 {
#             background-color:  #05659f;
#             color:  #f1f1f1;
#         }    #T_916c40e4_dc5b_11e9_9f7e_309c23131503row4_col0 {
#             background-color:  #86b0d3;
#             color:  #000000;
#         }    #T_916c40e4_dc5b_11e9_9f7e_309c23131503row4_col1 {
#             background-color:  #2081b9;
#             color:  #000000;
#         }    #T_916c40e4_dc5b_11e9_9f7e_309c23131503row4_col2 {
#             background-color:  #71a8ce;
#             color:  #000000;
#         }    #T_916c40e4_dc5b_11e9_9f7e_309c23131503row4_col3 {
#             background-color:  #056ba7;
#             color:  #f1f1f1;
#         }    #T_916c40e4_dc5b_11e9_9f7e_309c23131503row4_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }</style><table id="T_916c40e4_dc5b_11e9_9f7e_309c23131503" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >wins</th>        <th class="col_heading level0 col1" >goals</th>        <th class="col_heading level0 col2" >goal_fastbreak</th>        <th class="col_heading level0 col3" >total_scoring_att</th>        <th class="col_heading level0 col4" >ontarget_scoring_att</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_916c40e4_dc5b_11e9_9f7e_309c23131503level0_row0" class="row_heading level0 row0" >wins</th>
#                         <td id="T_916c40e4_dc5b_11e9_9f7e_309c23131503row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_916c40e4_dc5b_11e9_9f7e_309c23131503row0_col1" class="data row0 col1" >0.85</td>
#                         <td id="T_916c40e4_dc5b_11e9_9f7e_309c23131503row0_col2" class="data row0 col2" >0.5</td>
#                         <td id="T_916c40e4_dc5b_11e9_9f7e_309c23131503row0_col3" class="data row0 col3" >0.71</td>
#                         <td id="T_916c40e4_dc5b_11e9_9f7e_309c23131503row0_col4" class="data row0 col4" >0.73</td>
#             </tr>
#             <tr>
#                         <th id="T_916c40e4_dc5b_11e9_9f7e_309c23131503level0_row1" class="row_heading level0 row1" >goals</th>
#                         <td id="T_916c40e4_dc5b_11e9_9f7e_309c23131503row1_col0" class="data row1 col0" >0.85</td>
#                         <td id="T_916c40e4_dc5b_11e9_9f7e_309c23131503row1_col1" class="data row1 col1" >1</td>
#                         <td id="T_916c40e4_dc5b_11e9_9f7e_309c23131503row1_col2" class="data row1 col2" >0.18</td>
#                         <td id="T_916c40e4_dc5b_11e9_9f7e_309c23131503row1_col3" class="data row1 col3" >0.66</td>
#                         <td id="T_916c40e4_dc5b_11e9_9f7e_309c23131503row1_col4" class="data row1 col4" >0.74</td>
#             </tr>
#             <tr>
#                         <th id="T_916c40e4_dc5b_11e9_9f7e_309c23131503level0_row2" class="row_heading level0 row2" >goal_fastbreak</th>
#                         <td id="T_916c40e4_dc5b_11e9_9f7e_309c23131503row2_col0" class="data row2 col0" >0.5</td>
#                         <td id="T_916c40e4_dc5b_11e9_9f7e_309c23131503row2_col1" class="data row2 col1" >0.18</td>
#                         <td id="T_916c40e4_dc5b_11e9_9f7e_309c23131503row2_col2" class="data row2 col2" >1</td>
#                         <td id="T_916c40e4_dc5b_11e9_9f7e_309c23131503row2_col3" class="data row2 col3" >0.77</td>
#                         <td id="T_916c40e4_dc5b_11e9_9f7e_309c23131503row2_col4" class="data row2 col4" >0.6</td>
#             </tr>
#             <tr>
#                         <th id="T_916c40e4_dc5b_11e9_9f7e_309c23131503level0_row3" class="row_heading level0 row3" >total_scoring_att</th>
#                         <td id="T_916c40e4_dc5b_11e9_9f7e_309c23131503row3_col0" class="data row3 col0" >0.71</td>
#                         <td id="T_916c40e4_dc5b_11e9_9f7e_309c23131503row3_col1" class="data row3 col1" >0.66</td>
#                         <td id="T_916c40e4_dc5b_11e9_9f7e_309c23131503row3_col2" class="data row3 col2" >0.77</td>
#                         <td id="T_916c40e4_dc5b_11e9_9f7e_309c23131503row3_col3" class="data row3 col3" >1</td>
#                         <td id="T_916c40e4_dc5b_11e9_9f7e_309c23131503row3_col4" class="data row3 col4" >0.92</td>
#             </tr>
#             <tr>
#                         <th id="T_916c40e4_dc5b_11e9_9f7e_309c23131503level0_row4" class="row_heading level0 row4" >ontarget_scoring_att</th>
#                         <td id="T_916c40e4_dc5b_11e9_9f7e_309c23131503row4_col0" class="data row4 col0" >0.73</td>
#                         <td id="T_916c40e4_dc5b_11e9_9f7e_309c23131503row4_col1" class="data row4 col1" >0.74</td>
#                         <td id="T_916c40e4_dc5b_11e9_9f7e_309c23131503row4_col2" class="data row4 col2" >0.6</td>
#                         <td id="T_916c40e4_dc5b_11e9_9f7e_309c23131503row4_col3" class="data row4 col3" >0.92</td>
#                         <td id="T_916c40e4_dc5b_11e9_9f7e_309c23131503row4_col4" class="data row4 col4" >1</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# - Dengan mengetahui korelasi diatas dapat diketahui bahwa ternyata hubungan antara kemenangan dan jumlah shot itu ternyata positif dan cukup kuat.
# - Dengan kata lain dengan bertambahnya jumlah shot maka kemungkinan besar MU akan menang akan bertambah.
# ***
# - Mungkin dari sini bisa dilihat bahwa MU harus mencari pemain penyerang ataupun gelandang yang berani shot atau memiliki akurasi shot yang tinggi.
# - Di era sir alex, banyak sekali pemain dengan tipikal shooter seperti scholes, CR7, Tevez, Carrick, Rooney.

# %% [markdown]
# ### 7.3 Midfielder Analysis
# - Analisis akan menggunakan 3 features:
#     1. total_pass = jumlah passes
#     2. total_through_ball = jumlah umpan terobosan
#     3. total_cross = jumlah crossing

# %%
#Analisis total pass, through ball, dan long balls
f = plt.figure(figsize=(20,5))

f.add_subplot(1,2,1)
sns.lineplot(utd['season'], utd['total_pass'])
plt.xticks(rotation=45)

f.add_subplot(1,2,2)
sns.lineplot(utd['season'], utd['total_through_ball'])
plt.xticks(rotation=45)

f.tight_layout()
plt.show()

# %% [markdown]
# - Wow Ternyata semakin tahun nilai total_passes semakin naik, tetapi kok total_goalsnya semakin dikit ya ? kalau menurut saya ada 2 kemungkinan yaitu:
#     1. penyelesaian akhir yang kurang bagus dari pemain depan MU atau mungkin memang MU menginisiasi untuk bermain possession ball.
# - Lalu untuk umpan terobosan dapat dilihat bahwa mempunyai trend yang menurun. Walaupun total pass MU semakin naik, tapi umpan terobosan malah semakin turun. Menurut saya ada 2 kemungkinan juga yaitu:
#     1. Semakin modern sepakbola semakin rapi pertahanan dan susah untuk melakukan through pass.
#     2. Midfielder dari MU kurang kreativitas untuk mencari celah pertahanan.

# %%
#Analisis total_cross
plt.figure(figsize=(10,5))

plt.plot(utd['season'], utd['total_cross'])
plt.xlabel('Season')
plt.ylabel('Numbers')
plt.xticks(rotation=45)

plt.legend(labels=['total cross'])
plt.show()

# %% [markdown]
# - Dapat dilihat bahwa setelah sir alex pensiun, jumlah crossing menurun sangat signifikan yak. Disini ada 2 kemungkinan menurut analisis saya:
#     1. Gaya permainan pelatih setelah sir alex beda, mungkin david moyes atau van gall lebih suka bermain dari tengah sedangkan sir alex lebih suka memanfaatkan attacking dari winger.
#     2. Setelah ditinggal CR7, Giggs, Nani mungkin belum ada pengganti winger yang cocok.

# %%
#lihat korelasi
utd[['wins', 'total_pass', 'total_through_ball', 'total_cross']].corr().style.background_gradient().set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_0d3f6f8c_dc5d_11e9_b18d_309c23131503row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0d3f6f8c_dc5d_11e9_b18d_309c23131503row0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0d3f6f8c_dc5d_11e9_b18d_309c23131503row0_col2 {
#             background-color:  #6da6cd;
#             color:  #000000;
#         }    #T_0d3f6f8c_dc5d_11e9_b18d_309c23131503row0_col3 {
#             background-color:  #529bc7;
#             color:  #000000;
#         }    #T_0d3f6f8c_dc5d_11e9_b18d_309c23131503row1_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0d3f6f8c_dc5d_11e9_b18d_309c23131503row1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0d3f6f8c_dc5d_11e9_b18d_309c23131503row1_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0d3f6f8c_dc5d_11e9_b18d_309c23131503row1_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0d3f6f8c_dc5d_11e9_b18d_309c23131503row2_col0 {
#             background-color:  #4697c4;
#             color:  #000000;
#         }    #T_0d3f6f8c_dc5d_11e9_b18d_309c23131503row2_col1 {
#             background-color:  #e4e1ef;
#             color:  #000000;
#         }    #T_0d3f6f8c_dc5d_11e9_b18d_309c23131503row2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0d3f6f8c_dc5d_11e9_b18d_309c23131503row2_col3 {
#             background-color:  #056fae;
#             color:  #f1f1f1;
#         }    #T_0d3f6f8c_dc5d_11e9_b18d_309c23131503row3_col0 {
#             background-color:  #4496c3;
#             color:  #000000;
#         }    #T_0d3f6f8c_dc5d_11e9_b18d_309c23131503row3_col1 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_0d3f6f8c_dc5d_11e9_b18d_309c23131503row3_col2 {
#             background-color:  #0d75b3;
#             color:  #f1f1f1;
#         }    #T_0d3f6f8c_dc5d_11e9_b18d_309c23131503row3_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }</style><table id="T_0d3f6f8c_dc5d_11e9_b18d_309c23131503" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >wins</th>        <th class="col_heading level0 col1" >total_pass</th>        <th class="col_heading level0 col2" >total_through_ball</th>        <th class="col_heading level0 col3" >total_cross</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0d3f6f8c_dc5d_11e9_b18d_309c23131503level0_row0" class="row_heading level0 row0" >wins</th>
#                         <td id="T_0d3f6f8c_dc5d_11e9_b18d_309c23131503row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_0d3f6f8c_dc5d_11e9_b18d_309c23131503row0_col1" class="data row0 col1" >-0.38</td>
#                         <td id="T_0d3f6f8c_dc5d_11e9_b18d_309c23131503row0_col2" class="data row0 col2" >0.44</td>
#                         <td id="T_0d3f6f8c_dc5d_11e9_b18d_309c23131503row0_col3" class="data row0 col3" >0.44</td>
#             </tr>
#             <tr>
#                         <th id="T_0d3f6f8c_dc5d_11e9_b18d_309c23131503level0_row1" class="row_heading level0 row1" >total_pass</th>
#                         <td id="T_0d3f6f8c_dc5d_11e9_b18d_309c23131503row1_col0" class="data row1 col0" >-0.38</td>
#                         <td id="T_0d3f6f8c_dc5d_11e9_b18d_309c23131503row1_col1" class="data row1 col1" >1</td>
#                         <td id="T_0d3f6f8c_dc5d_11e9_b18d_309c23131503row1_col2" class="data row1 col2" >-0.16</td>
#                         <td id="T_0d3f6f8c_dc5d_11e9_b18d_309c23131503row1_col3" class="data row1 col3" >-0.3</td>
#             </tr>
#             <tr>
#                         <th id="T_0d3f6f8c_dc5d_11e9_b18d_309c23131503level0_row2" class="row_heading level0 row2" >total_through_ball</th>
#                         <td id="T_0d3f6f8c_dc5d_11e9_b18d_309c23131503row2_col0" class="data row2 col0" >0.44</td>
#                         <td id="T_0d3f6f8c_dc5d_11e9_b18d_309c23131503row2_col1" class="data row2 col1" >-0.16</td>
#                         <td id="T_0d3f6f8c_dc5d_11e9_b18d_309c23131503row2_col2" class="data row2 col2" >1</td>
#                         <td id="T_0d3f6f8c_dc5d_11e9_b18d_309c23131503row2_col3" class="data row2 col3" >0.69</td>
#             </tr>
#             <tr>
#                         <th id="T_0d3f6f8c_dc5d_11e9_b18d_309c23131503level0_row3" class="row_heading level0 row3" >total_cross</th>
#                         <td id="T_0d3f6f8c_dc5d_11e9_b18d_309c23131503row3_col0" class="data row3 col0" >0.44</td>
#                         <td id="T_0d3f6f8c_dc5d_11e9_b18d_309c23131503row3_col1" class="data row3 col1" >-0.3</td>
#                         <td id="T_0d3f6f8c_dc5d_11e9_b18d_309c23131503row3_col2" class="data row3 col2" >0.69</td>
#                         <td id="T_0d3f6f8c_dc5d_11e9_b18d_309c23131503row3_col3" class="data row3 col3" >1</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# - Dari nilai korelasi diatas mungkin bisa ditarik beberapa kesimpulan yaitu:
#     1. Ternyata total pass mempunyai korelasi negative dengan wins. Ini mungkin karena passing di MU kurang efektif hanya passing-passing yang tidak jelas dan akhirnya tidak menjadi goal.
#     2. Untuk umpan terobosan, mempunyai korelasi yang positif dan cukup kuat. Sehingga perlu menambah umpan terobosan agar bisa mencetak lebih banyak goals dan bisa menang.
#     3. Yap jumlah wins dan total_cross mempunyai korelasi positif yang sangat kuat dimana semakin sering melakukan crossing bola ke depan gawang maka akan semakin besar kemungkinan untuk mencetak goal dan meningkatkan peluang MU untuk menang.
# ***
# - Jadi menurut analisis saya, MU harus mencari gelandang yang kreatif dan memiliki visi yang bagus. Seperti Hazard, Kevin de Bruyne atau Luka Modric.
# - Tidak hanya bagus di passing, tetapi juga pintar mencari celah untuk memberikan umpan terobosan.
# - Menambah kekuatan di sisi winger menurut saya bisa menambah peluang untuk meraih kemenangan.

# %% [markdown]
# ### 7.4 Defender Analysis
# - Analisis defender menggunakan 3 features yaitu:
#     1. clean_sheet = jumlah pertandingan yang tidak mengalami kebobolan
#     2. goals_conceded = jumlah kebobolan
#     3. total_tackle = total tackle

# %%
#Analisis clean_sheet dan goals_conceded
f = plt.figure(figsize=(20,5))

f.add_subplot(1,2,1)
sns.lineplot(utd['season'], utd['clean_sheet'])
plt.xticks(rotation=45)

f.add_subplot(1,2,2)
sns.lineplot(utd['season'], utd['goals_conceded'])
plt.xticks(rotation=45)

f.tight_layout()
plt.show()

# %% [markdown]
# - Untuk clean sheet merupakan perpaduan dari defender dan goalkeeper. Trendnya sangat fluktuatif dan saya pikir features ini antara era sir alex dan setelah sir alex 11 12.
# - Untuk jumlah kebobolan, di era sir alex trendnya naik sampai pada akhirnya turun lagi setelah sir alex pensiun.
# ***
# - Kemungkinan jumlah kebobolan menurun ada 2 faktor:
#     1. Gaya permainan menyerang sir alex sehingga dari sisi defence agak sedikit kurang.
#     2. Beberapa manager setelah sir alex menerapkan gaya permainan parkir bus seperti jose mourinho sehingga sedikit mengalami kebobolan.

# %%
#Analisis total_tackle dan defence
plt.figure(figsize=(10,5))
sns.lineplot(utd['season'], utd['total_tackle'])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# - Jika dilihat dari sisi tackle, trendnya lebih condong untuk turun dimana semakin tahun jumlah tackle semakin sedikit. Menurut analisis saya ini karena ada 2 kemungkinan yaitu:
#     1. Defender dari MU setelah sir alex era kurang berani bermain prok prok jika dibandingkan dengan vidic ataupun ferdinand.
#     2. semakin modern semakin bola maka defender juga semakin berhati-hati untuk melakukan tackle dan hanya melakukan tackle ketika diperlukan saja.
# - Untuk defence yaitu gabungan dari block + interception + clearence, trendnya sangat fluktuatif.

# %%
#lihat korelasi
utd[['wins', 'total_tackle', 'clean_sheet', 'goals_conceded']].corr().style.background_gradient().set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_08a55f12_dc65_11e9_8f3c_309c23131503row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_08a55f12_dc65_11e9_8f3c_309c23131503row0_col1 {
#             background-color:  #3d93c2;
#             color:  #000000;
#         }    #T_08a55f12_dc65_11e9_8f3c_309c23131503row0_col2 {
#             background-color:  #157ab5;
#             color:  #000000;
#         }    #T_08a55f12_dc65_11e9_8f3c_309c23131503row0_col3 {
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }    #T_08a55f12_dc65_11e9_8f3c_309c23131503row1_col0 {
#             background-color:  #4094c3;
#             color:  #000000;
#         }    #T_08a55f12_dc65_11e9_8f3c_309c23131503row1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_08a55f12_dc65_11e9_8f3c_309c23131503row1_col2 {
#             background-color:  #4697c4;
#             color:  #000000;
#         }    #T_08a55f12_dc65_11e9_8f3c_309c23131503row1_col3 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_08a55f12_dc65_11e9_8f3c_309c23131503row2_col0 {
#             background-color:  #358fc0;
#             color:  #000000;
#         }    #T_08a55f12_dc65_11e9_8f3c_309c23131503row2_col1 {
#             background-color:  #78abd0;
#             color:  #000000;
#         }    #T_08a55f12_dc65_11e9_8f3c_309c23131503row2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_08a55f12_dc65_11e9_8f3c_309c23131503row2_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_08a55f12_dc65_11e9_8f3c_309c23131503row3_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_08a55f12_dc65_11e9_8f3c_309c23131503row3_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_08a55f12_dc65_11e9_8f3c_309c23131503row3_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_08a55f12_dc65_11e9_8f3c_309c23131503row3_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }</style><table id="T_08a55f12_dc65_11e9_8f3c_309c23131503" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >wins</th>        <th class="col_heading level0 col1" >total_tackle</th>        <th class="col_heading level0 col2" >clean_sheet</th>        <th class="col_heading level0 col3" >goals_conceded</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_08a55f12_dc65_11e9_8f3c_309c23131503level0_row0" class="row_heading level0 row0" >wins</th>
#                         <td id="T_08a55f12_dc65_11e9_8f3c_309c23131503row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_08a55f12_dc65_11e9_8f3c_309c23131503row0_col1" class="data row0 col1" >0.44</td>
#                         <td id="T_08a55f12_dc65_11e9_8f3c_309c23131503row0_col2" class="data row0 col2" >0.47</td>
#                         <td id="T_08a55f12_dc65_11e9_8f3c_309c23131503row0_col3" class="data row0 col3" >-0.41</td>
#             </tr>
#             <tr>
#                         <th id="T_08a55f12_dc65_11e9_8f3c_309c23131503level0_row1" class="row_heading level0 row1" >total_tackle</th>
#                         <td id="T_08a55f12_dc65_11e9_8f3c_309c23131503row1_col0" class="data row1 col0" >0.44</td>
#                         <td id="T_08a55f12_dc65_11e9_8f3c_309c23131503row1_col1" class="data row1 col1" >1</td>
#                         <td id="T_08a55f12_dc65_11e9_8f3c_309c23131503row1_col2" class="data row1 col2" >0.27</td>
#                         <td id="T_08a55f12_dc65_11e9_8f3c_309c23131503row1_col3" class="data row1 col3" >-0.44</td>
#             </tr>
#             <tr>
#                         <th id="T_08a55f12_dc65_11e9_8f3c_309c23131503level0_row2" class="row_heading level0 row2" >clean_sheet</th>
#                         <td id="T_08a55f12_dc65_11e9_8f3c_309c23131503row2_col0" class="data row2 col0" >0.47</td>
#                         <td id="T_08a55f12_dc65_11e9_8f3c_309c23131503row2_col1" class="data row2 col1" >0.27</td>
#                         <td id="T_08a55f12_dc65_11e9_8f3c_309c23131503row2_col2" class="data row2 col2" >1</td>
#                         <td id="T_08a55f12_dc65_11e9_8f3c_309c23131503row2_col3" class="data row2 col3" >-0.8</td>
#             </tr>
#             <tr>
#                         <th id="T_08a55f12_dc65_11e9_8f3c_309c23131503level0_row3" class="row_heading level0 row3" >goals_conceded</th>
#                         <td id="T_08a55f12_dc65_11e9_8f3c_309c23131503row3_col0" class="data row3 col0" >-0.41</td>
#                         <td id="T_08a55f12_dc65_11e9_8f3c_309c23131503row3_col1" class="data row3 col1" >-0.44</td>
#                         <td id="T_08a55f12_dc65_11e9_8f3c_309c23131503row3_col2" class="data row3 col2" >-0.8</td>
#                         <td id="T_08a55f12_dc65_11e9_8f3c_309c23131503row3_col3" class="data row3 col3" >1</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# - Korelasi antara wins dan total_tackle cukup kuat dimana jika MU melakukan banyak tackle maka kemungkinan untuk menang akan lebih besar. Karena dengan melakukan banyak tackle maka kita telah menggagalkan penyerangan lawan. Sehingga akan mengurangi kemungkinan kebobolan dan meningkatkan peluang kemenangan.
# - Korelasi antara wins dan clean sheet cukup kuat dimana jika MU clean sheet maka kemungkinan untuk menang akan lebih besar.
# - Sedangkan hubungan wins dan kebobolan berkebalikan dimana MU mengalami kebobolan, maka kemungkinan untuk menang akan sedikit.
# ***
# - Jadi menurut analisis saya, MU harus berani invest ke defender yang memang pintar membaca kondisi dan berani bertarung.
# - Belum ada yang bisa mengganti peran dari vidic ataupun ferdinand ataupun evra. Mungkin maguire dan AWB ?

# %% [markdown]
# ## 8. Kesimpulan

# %% [markdown]
# - Jadi menurut analisis yang telah saya lakukan, dapat saya tarik beberapa kesimpulan bahwa memang di era sir alex MU lebih bisa menjadi setan merah yang benar-benar setan sehingga bisa meraih banyak trophy jika dibandingkan era MU setelah sir alex pensiun.
# - Ada beberapa faktor yang mempengaruhi seperti:
#     1. Faktor sir alex itu sendiri, ibaratnya sir alex adalah orang yang tidak tergantikan di MU. Bahkan mendapat gelar'Sir' dari perdana menteri inggris karena prestasinya.
#     2. Faktor pemain, banyak pemain kunci MU yang mulai hilang dan belum ada pengganti yang cocok seperti CR7, scholes, giggs, tevez, berbatov sehingga mengganggu kedalaman skuad MU.
#     3. Sepakbola semakin modern dimana untuk mengunci kemenangan tidak hanya dibutuhkan taktik saja, tetapi juga peran teknologi sekarang mulai berperan dalam dunia sepakbola.
